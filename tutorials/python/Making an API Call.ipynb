# %% [markdown]
# # Welcome to Receptiviti!
#
# Are you looking for a quick snippet or two to make a call to the Receptiviti API?
# You've come to the right place!
#
# This Jupyter Notebook will get you started with code to simplify calling the API.
# Let's begin with
#
# ## Step 1 - Your API Keys
# **Don't forget to add your API key and secret into the following cell**

# %%
API_KEY = ''
API_SECRET = ''
API_URL = 'https://api.receptiviti.com/v1/score'

# %% [markdown]
# ## Step 2 - Install python libraries
#
# If you are running this notebook within a Google Colab environment, you can skip ahead to [Step 3](#Step-3---Create-a-simple-API-call-helper). Google Colab provides all the requisite python libraries you will need to execute this Jupyter Notebook.
#
# If you are running this notebook locally or on your own server setup, determine if your system uses Conda or Pip to manage python dependencies. If you prefer Conda, follow the instructions [here](#Option-2---Conda) to install the requisite python libraries. If you prefer Pip, follow the instructions [here](#Option-3---Pip).
#
# ***Remember*** that you will only need to use either Conda ***or*** Pip to set up your python environment locally - not both.
#
# ### Option 1 - Google Colab
# Skip ahead to [Step 3](#Step-3---Create-a-simple-API-call-helper). You're all set!

# %% [markdown]
# ### Option 2 - Conda
# Uncomment the cell below and run

# %%
# import sys
# !conda install --yes --prefix {sys.prefix} requests

# %% [markdown]
# ### Option 3 - Pip
# Uncomment the cell below and run

# %%
# import sys
# !{sys.executable} -m pip install requests

# %% [markdown]
# ## Step 3 - Create a simple API call helper

# %%
import json
import requests

def get_payload_and_url(text):
    if len(text)<1:
        print("ERROR: 'text' should not be empty")
        return {}
    if isinstance(text, str):
        return ({
                    "content": text
                }, API_URL)
    if isinstance(text, list):
        return ([{
                    "content": content
        } for content in text], API_URL + '/bulk')

def call_receptiviti_api(text):
    payload, url = get_payload_and_url(text)
    results = []
    if len(payload)>0:
        response = requests.post(url, data=json.dumps(payload), auth=(API_KEY, API_SECRET), headers = {'Content-Type': 'application/json'})
        if response.status_code==200:
            results = response.json()
    return results

# %% [markdown]
# ## Step 4 - Make a single call

# %%
print("Single Call to Receptiviti API")
result = call_receptiviti_api("Hi How are you?")
result
# Out:
# Single Call to Receptiviti API
# {'plan_usage': {'word_limit': 250000,
#   'words_used': 5747,
#   'words_remaining': 244253,
#   'percent_used': 2.3,
#   'start_date': '2021-01-01T00:00:00Z',
#   'end_date': '2021-01-31T23:59:59Z'},
#  'results': [{'response_id': '10455256-9e4e-4a3f-951b-b2a116a02ecc',
#    'language': 'en',
#    'version': 'v1.0.0',
#    'summary': {'word_count': 4,
#     'words_per_sentence': 4,
#     'sentence_count': 1,
#     'six_plus_words': 0,
#     'emojis': 0,
#     'emoticons': 0,
#     'hashtags': 0,
#     'urls': 0},
#    'dictionary_measures': {'achievement': 0,
#     'adjectives': 0,
#     'admiration': 0,
#     'adverbs': 0.25,
#     'affective_processes': 0,
#     'affiliation': 0.25,
#     'all_punctuation': 0.25,
#     'ambifeel': 0,
#     'amusement': 0,
#     'analytical_thinking': 0,
#     'anger': 0,
#     'anger_words': 0,
#     'anxiety_words': 0,
#     'apostrophes': 0,
#     'articles': 0,
#     'assent': 0,
#     'authentic': 0.01,
#     'auxiliary_verbs': 0.25,
#     'badfeel': 0,
#     'biological_processes': 0,
#     'body': 0,
#     'boredom': 0,
#     'calmness': 0,
#     'causation': 0,
#     'certainty': 0,
#     'clout': 0.99,
#     'cognitive_processes': 0,
#     'colons': 0,
#     'commas': 0,
#     'comparisons': 0,
#     'conjunctions': 0.25,
#     'curiosity': 0,
#     'dashes': 0,
#     'death': 0,
#     'dictionary_words': 1,
#     'differentiation': 0,
#     'discrepancies': 0,
#     'disgust': 0,
#     'drives': 0.25,
#     'emotional_tone': 0.257741935483871,
#     'emotionality': 0,
#     'excitement': 0,
#     'exclamations': 0,
#     'external_focus': 0.25,
#     'family': 0,
#     'fear': 0,
#     'feel': 0,
#     'female': 0,
#     'filler_words': 0,
#     'focus_future': 0,
#     'focus_past': 0,
#     'focus_present': 0,
#     'friends': 0,
#     'function_words': 0.75,
#     'goodfeel': 0,
#     'gratitude': 0,
#     'health': 0,
#     'hear': 0,
#     'home': 0,
#     'i': 0,
#     'impersonal_pronouns': 0,
#     'informal_language': 0,
#     'ingestion': 0,
#     'insight': 0,
#     'interrogatives': 0.25,
#     'joy': 0,
#     'leisure': 0,
#     'love': 0,
#     'male': 0,
#     'money': 0,
#     'motion': 0,
#     'negations': 0,
#     'negative_emotion_words': 0,
#     'netspeak': 0,
#     'non_emotion': 1,
#     'nonfluencies': 0,
#     'numbers': 0,
#     'other_grammar': 0.5,
#     'other_punctuation': 0,
#     'parentheses': 0,
#     'perceptual_processes': 0,
#     'periods': 0,
#     'personal_concerns': 0,
#     'personal_pronouns': 0.25,
#     'positive_emotion_words': 0,
#     'power': 0,
#     'prepositions': 0,
#     'pronouns': 0.25,
#     'quantifiers': 0,
#     'question_marks': 0.25,
#     'quotes': 0,
#     'relativity': 0,
#     'religion': 0,
#     'reward': 0,
#     'risk': 0,
#     'sad_words': 0,
#     'sadness': 0,
#     'see': 0,
#     'self_focus': 0,
#     'semicolons': 0,
#     'sentiment': 0,
#     'sexual': 0,
#     'she_he': 0,
#     'six_plus_words': 0,
#     'social_processes': 0.5,
#     'space': 0,
#     'surprise': 0,
#     'swear_words': 0,
#     'tentative': 0,
#     'they': 0,
#     'time': 0,
#     'time_orientation': 0.25,
#     'verbs': 0.25,
#     'we': 0,
#     'work': 0,
#     'you': 0.25},
#    'receptiviti_measures': {'achievement': 0.48532467911884425,
#     'active': 35.18603703195992,
#     'adventurous': 48.080957197440036,
#     'affiliation': 100,
#     'aggressive': 30.241496879122238,
#     'agreeableness': 54.8426086232612,
#     'ambitious': 18.493090834834856,
#     'anxiety_prone': 42.50185897409756,
#     'artistic': 33.46423574279875,
#     'assertive': 41.416308884375944,
#     'authentic': 0.6441581519324745,
#     'cautious': 30.964451643881905,
#     'cheerful': 39.55617495810961,
#     'clout': 100,
#     'conscientiousness': 28.985834304646847,
#     'cooperative': 58.76109532563836,
#     'disciplined': 43.88165758571944,
#     'dutiful': 23.805969899603202,
#     'emotionally_aware': 22.286152737569655,
#     'empathetic': 53.42302127770554,
#     'energetic': 61.705804355998325,
#     'extraversion': 49.10633717551565,
#     'friendly': 64.14345511802709,
#     'generous': 30.55749908347561,
#     'genuine': 79.96761937526313,
#     'humble': 81.91816479623337,
#     'imaginative': 6.973891102604497,
#     'impulsive': 66.675947822711,
#     'intellectual': 2.6860081814943984,
#     'inward_focus': 2.068432909478152,
#     'liberal': 69.54472361080133,
#     'melancholy': 40.73870171022978,
#     'negations': 0.8980513763095138,
#     'neuroticism': 42.66067808167354,
#     'openness': 24.491659123619772,
#     'organized': 3.520454866126516,
#     'outward_focus': 100,
#     'power': 0.03942505620063466,
#     'reward': 0.28094650555036105,
#     'risk_aversion': 54.29808973789427,
#     'risk_seeking': 4.609062638827187,
#     'self_assured': 57.773391808844075,
#     'self_conscious': 16.449869248686145,
#     'sociable': 57.786051636941494,
#     'social': 100,
#     'stress_prone': 80.44593613238416,
#     'trusting': 72.05779027759215}}]}

# %% [markdown]
# ## Step 5 - Make a bulk call

# %%
print("Bulk Call to Receptiviti API")
result = call_receptiviti_api([
                                "Hi, How are you?", 
                                "Hello world! I love icecream and watermelons!"
                            ])
result
# Out:
# Bulk Call to Receptiviti API
# {'plan_usage': {'word_limit': 250000,
#   'words_used': 5758,
#   'words_remaining': 244242,
#   'percent_used': 2.3,
#   'start_date': '2021-01-01T00:00:00Z',
#   'end_date': '2021-01-31T23:59:59Z'},
#  'results': [{'response_id': 'a677fe67-9def-4e37-b78b-e21bef9174b0',
#    'language': 'en',
#    'version': 'v1.0.0',
#    'summary': {'word_count': 4,
#     'words_per_sentence': 4,
#     'sentence_count': 1,
#     'six_plus_words': 0,
#     'emojis': 0,
#     'emoticons': 0,
#     'hashtags': 0,
#     'urls': 0},
#    'dictionary_measures': {'achievement': 0,
#     'adjectives': 0,
#     'admiration': 0,
#     'adverbs': 0.25,
#     'affective_processes': 0,
#     'affiliation': 0.25,
#     'all_punctuation': 0.5,
#     'ambifeel': 0,
#     'amusement': 0,
#     'analytical_thinking': 0,
#     'anger': 0,
#     'anger_words': 0,
#     'anxiety_words': 0,
#     'apostrophes': 0,
#     'articles': 0,
#     'assent': 0,
#     'authentic': 0.01,
#     'auxiliary_verbs': 0.25,
#     'badfeel': 0,
#     'biological_processes': 0,
#     'body': 0,
#     'boredom': 0,
#     'calmness': 0,
#     'causation': 0,
#     'certainty': 0,
#     'clout': 0.99,
#     'cognitive_processes': 0,
#     'colons': 0,
#     'commas': 0.25,
#     'comparisons': 0,
#     'conjunctions': 0.25,
#     'curiosity': 0,
#     'dashes': 0,
#     'death': 0,
#     'dictionary_words': 1,
#     'differentiation': 0,
#     'discrepancies': 0,
#     'disgust': 0,
#     'drives': 0.25,
#     'emotional_tone': 0.257741935483871,
#     'emotionality': 0,
#     'excitement': 0,
#     'exclamations': 0,
#     'external_focus': 0.25,
#     'family': 0,
#     'fear': 0,
#     'feel': 0,
#     'female': 0,
#     'filler_words': 0,
#     'focus_future': 0,
#     'focus_past': 0,
#     'focus_present': 0,
#     'friends': 0,
#     'function_words': 0.75,
#     'goodfeel': 0,
#     'gratitude': 0,
#     'health': 0,
#     'hear': 0,
#     'home': 0,
#     'i': 0,
#     'impersonal_pronouns': 0,
#     'informal_language': 0,
#     'ingestion': 0,
#     'insight': 0,
#     'interrogatives': 0.25,
#     'joy': 0,
#     'leisure': 0,
#     'love': 0,
#     'male': 0,
#     'money': 0,
#     'motion': 0,
#     'negations': 0,
#     'negative_emotion_words': 0,
#     'netspeak': 0,
#     'non_emotion': 1,
#     'nonfluencies': 0,
#     'numbers': 0,
#     'other_grammar': 0.5,
#     'other_punctuation': 0,
#     'parentheses': 0,
#     'perceptual_processes': 0,
#     'periods': 0,
#     'personal_concerns': 0,
#     'personal_pronouns': 0.25,
#     'positive_emotion_words': 0,
#     'power': 0,
#     'prepositions': 0,
#     'pronouns': 0.25,
#     'quantifiers': 0,
#     'question_marks': 0.25,
#     'quotes': 0,
#     'relativity': 0,
#     'religion': 0,
#     'reward': 0,
#     'risk': 0,
#     'sad_words': 0,
#     'sadness': 0,
#     'see': 0,
#     'self_focus': 0,
#     'semicolons': 0,
#     'sentiment': 0,
#     'sexual': 0,
#     'she_he': 0,
#     'six_plus_words': 0,
#     'social_processes': 0.5,
#     'space': 0,
#     'surprise': 0,
#     'swear_words': 0,
#     'tentative': 0,
#     'they': 0,
#     'time': 0,
#     'time_orientation': 0.25,
#     'verbs': 0.25,
#     'we': 0,
#     'work': 0,
#     'you': 0.25},
#    'receptiviti_measures': {'achievement': 0.48532467911884425,
#     'active': 35.18603703195992,
#     'adventurous': 48.080957197440036,
#     'affiliation': 100,
#     'aggressive': 30.241496879122238,
#     'agreeableness': 54.8426086232612,
#     'ambitious': 18.493090834834856,
#     'anxiety_prone': 42.50185897409756,
#     'artistic': 33.46423574279875,
#     'assertive': 41.416308884375944,
#     'authentic': 0.6441581519324745,
#     'cautious': 30.964451643881905,
#     'cheerful': 39.55617495810961,
#     'clout': 100,
#     'conscientiousness': 28.985834304646847,
#     'cooperative': 58.76109532563836,
#     'disciplined': 43.88165758571944,
#     'dutiful': 23.805969899603202,
#     'emotionally_aware': 22.286152737569655,
#     'empathetic': 53.42302127770554,
#     'energetic': 61.705804355998325,
#     'extraversion': 49.10633717551565,
#     'friendly': 64.14345511802709,
#     'generous': 30.55749908347561,
#     'genuine': 79.96761937526313,
#     'humble': 81.91816479623337,
#     'imaginative': 6.973891102604497,
#     'impulsive': 66.675947822711,
#     'intellectual': 2.6860081814943984,
#     'inward_focus': 2.068432909478152,
#     'liberal': 69.54472361080133,
#     'melancholy': 40.73870171022978,
#     'negations': 0.8980513763095138,
#     'neuroticism': 42.66067808167354,
#     'openness': 24.491659123619772,
#     'organized': 3.520454866126516,
#     'outward_focus': 100,
#     'power': 0.03942505620063466,
#     'reward': 0.28094650555036105,
#     'risk_aversion': 54.29808973789427,
#     'risk_seeking': 4.609062638827187,
#     'self_assured': 57.773391808844075,
#     'self_conscious': 16.449869248686145,
#     'sociable': 57.786051636941494,
#     'social': 100,
#     'stress_prone': 80.44593613238416,
#     'trusting': 72.05779027759215}},
#   {'response_id': '9e3d7737-4b0c-4664-8270-335b7cbbfb9e',
#    'language': 'en',
#    'version': 'v1.0.0',
#    'summary': {'word_count': 7,
#     'words_per_sentence': 3.5,
#     'sentence_count': 2,
#     'six_plus_words': 0.2857142857142857,
#     'emojis': 0,
#     'emoticons': 0,
#     'hashtags': 0,
#     'urls': 0},
#    'dictionary_measures': {'achievement': 0,
#     'adjectives': 0,
#     'admiration': 0,
#     'adverbs': 0,
#     'affective_processes': 0.14285714285714285,
#     'affiliation': 0.2857142857142857,
#     'all_punctuation': 0.2857142857142857,
#     'ambifeel': 0,
#     'amusement': 0,
#     'analytical_thinking': 0,
#     'anger': 0,
#     'anger_words': 0,
#     'anxiety_words': 0,
#     'apostrophes': 0,
#     'articles': 0,
#     'assent': 0,
#     'authentic': 0.8963463203463203,
#     'auxiliary_verbs': 0,
#     'badfeel': 0,
#     'biological_processes': 0.14285714285714285,
#     'body': 0,
#     'boredom': 0,
#     'calmness': 0,
#     'causation': 0,
#     'certainty': 0,
#     'clout': 0.9233199195171027,
#     'cognitive_processes': 0,
#     'colons': 0,
#     'commas': 0,
#     'comparisons': 0,
#     'conjunctions': 0.14285714285714285,
#     'curiosity': 0,
#     'dashes': 0,
#     'death': 0,
#     'dictionary_words': 0.7142857142857143,
#     'differentiation': 0,
#     'discrepancies': 0,
#     'disgust': 0,
#     'drives': 0.2857142857142857,
#     'emotional_tone': 0.99,
#     'emotionality': 0.5636998254799302,
#     'excitement': 0.06369982547993018,
#     'exclamations': 0.2857142857142857,
#     'external_focus': 0,
#     'family': 0,
#     'fear': 0,
#     'feel': 0,
#     'female': 0,
#     'filler_words': 0,
#     'focus_future': 0,
#     'focus_past': 0,
#     'focus_present': 0,
#     'friends': 0,
#     'function_words': 0.2857142857142857,
#     'goodfeel': 0.5636998254799302,
#     'gratitude': 0,
#     'health': 0,
#     'hear': 0,
#     'home': 0,
#     'i': 0.14285714285714285,
#     'impersonal_pronouns': 0,
#     'informal_language': 0,
#     'ingestion': 0,
#     'insight': 0,
#     'interrogatives': 0,
#     'joy': 0,
#     'leisure': 0,
#     'love': 0.5,
#     'male': 0,
#     'money': 0,
#     'motion': 0,
#     'negations': 0,
#     'negative_emotion_words': 0,
#     'netspeak': 0,
#     'non_emotion': 0.43630017452006975,
#     'nonfluencies': 0,
#     'numbers': 0,
#     'other_grammar': 0,
#     'other_punctuation': 0,
#     'parentheses': 0,
#     'perceptual_processes': 0,
#     'periods': 0,
#     'personal_concerns': 0,
#     'personal_pronouns': 0.14285714285714285,
#     'positive_emotion_words': 0.14285714285714285,
#     'power': 0,
#     'prepositions': 0,
#     'pronouns': 0.14285714285714285,
#     'quantifiers': 0,
#     'question_marks': 0,
#     'quotes': 0,
#     'relativity': 0.14285714285714285,
#     'religion': 0,
#     'reward': 0,
#     'risk': 0,
#     'sad_words': 0,
#     'sadness': 0,
#     'see': 0,
#     'self_focus': 0.14285714285714285,
#     'semicolons': 0,
#     'sentiment': 0.5636998254799302,
#     'sexual': 0,
#     'she_he': 0,
#     'six_plus_words': 0.2857142857142857,
#     'social_processes': 0.2857142857142857,
#     'space': 0.14285714285714285,
#     'surprise': 0,
#     'swear_words': 0,
#     'tentative': 0,
#     'they': 0,
#     'time': 0,
#     'time_orientation': 0,
#     'verbs': 0,
#     'we': 0,
#     'work': 0,
#     'you': 0},
#    'receptiviti_measures': {'achievement': 0.48532467911884425,
#     'active': 40.277572257967144,
#     'adventurous': 60.6815462423486,
#     'affiliation': 100,
#     'aggressive': 30.219154252273093,
#     'agreeableness': 59.742600763400304,
#     'ambitious': 24.328712510457983,
#     'anxiety_prone': 27.308851914684066,
#     'artistic': 53.87215936591951,
#     'assertive': 35.77318897628164,
#     'authentic': 57.06352732119058,
#     'cautious': 30.960721408616603,
#     'cheerful': 66.7417013297953,
#     'clout': 99.33362949800089,
#     'conscientiousness': 37.17450432441081,
#     'cooperative': 60.625466134735966,
#     'disciplined': 21.683786534282543,
#     'dutiful': 36.87931539030577,
#     'emotionally_aware': 26.986238072953597,
#     'empathetic': 61.538826756623585,
#     'energetic': 71.50626250203833,
#     'extraversion': 56.00647120304967,
#     'friendly': 68.68180791668652,
#     'generous': 54.68000984768465,
#     'genuine': 51.55011257138697,
#     'humble': 63.96943259668887,
#     'imaginative': 44.41017920647423,
#     'impulsive': 58.431937598704884,
#     'intellectual': 34.03381089484962,
#     'inward_focus': 92.34326391081922,
#     'liberal': 64.7160977404651,
#     'melancholy': 13.86173084247591,
#     'negations': 0.8980513763095138,
#     'neuroticism': 26.53729967941485,
#     'openness': 44.72855418699102,
#     'organized': 3.520454866126516,
#     'outward_focus': 0.5108840515326522,
#     'power': 0.03942505620063466,
#     'reward': 0.28094650555036105,
#     'risk_aversion': 54.29808973789427,
#     'risk_seeking': 4.609062638827187,
#     'self_assured': 89.51369993982071,
#     'self_conscious': 15.75469695350385,
#     'sociable': 58.51610679630202,
#     'social': 100,
#     'stress_prone': 34.6650225584977,
#     'trusting': 74.62096062312882}}]}

# %% [markdown]
# # Congratulations!
#
# Thanks for running through this tutorial with us! Now that you have scores from the Receptiviti API at your disposal, go ahead and check out some of the other tutorials on deriving insight from them.
#
# Check out our [Getting Started guide here](https://github.com/Receptiviti/api_tutorials_demos/blob/master/tutorials/python/Getting%20Started.ipynb)
#
# Check out our other [tutorials and demos here](https://dashboard.receptiviti.com/docs/tutorials)
