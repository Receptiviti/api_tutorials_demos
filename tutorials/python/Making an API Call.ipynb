# %% [markdown]
# # Welcome to Receptiviti!
#
# Are you looking for a quick snippet or two to make a call to the Receptiviti API?
# You've come to the right place!
#
# This jupyter notebook will get you started with code to simplify calling the API.
# Let's begin with
#
# ## Step 1 - Your API Keys
# **Don't forget to add your api key and secret into the following cell**

# %%
API_KEY = '<>'
API_SECRET = '<>'

# %% [markdown]
# # Step 2 - Install python libraries

# %% [markdown]
# ## If using conda
# Uncomment the cell below and run

# %%
# import sys
# !conda install --yes --prefix {sys.prefix} requests

# %% [markdown]
# ## If using pip
# Uncomment the cell below and run

# %%
# import sys
# !{sys.executable} -m pip install requests

# %% [markdown]
# ## Step 3 - Create a simple API call helper

# %%
import json
import requests

def get_payload(text, call_type="single"):
    if len(text)<1:
        print("ERROR: 'text' should not be empty")
        return {}
    if call_type=="single":
        if type(text)==list:
            print("WARNING: 'text' argument is a list and incompatible with a single call.\nUsing only the first element to construct the payload")
            text = text[0]
        return {
                    "content": text
                }
    if call_type=="bulk":
        if type(text)!=list:
            print("WARNING: 'text' argument is not a list and incompatible with a bulk call.\nConverting 'text' to a list of length 1")
            text = [text]
        return [{
                    "content": content
        } for content in text]

def call_receptiviti_api(text, call_type="single"):
    API_URL = 'https://api.receptiviti.com/v1/score'
    if call_type=="bulk":
        API_URL = 'https://api.receptiviti.com/v1/score/bulk'
    payload = get_payload(text, call_type)
    results = []
    if len(payload)>0:
        response = requests.post(API_URL, data=json.dumps(payload), auth=(API_KEY, API_SECRET), headers = {'Content-Type': 'application/json'})
        if response.status_code==200:
            results = response.json()
    return results

# %% [markdown]
# ## Step 4 - Make a single call

# %%
print("Single Call to Receptiviti API")
result = call_receptiviti_api("Hi How are you?")
result
# Out:
# Single Call to Receptiviti API
# {'plan_usage': {'call_limit': 107007130,
#   'calls_made': 468992,
#   'calls_remaining': 106538138,
#   'percent_used': 0.44,
#   'start_date': '2020-11-01T00:00:00Z',
#   'end_date': '2020-11-30T23:59:59Z'},
#  'results': [{'response_id': '86d89737-57a4-41ff-919a-558280cc5e69',
#    'language': 'en',
#    'version': 'v1.0.0',
#    'summary': {'word_count': 4,
#     'words_per_sentence': 4,
#     'sentence_count': 1,
#     'six_plus_words': 0,
#     'emojis': 0,
#     'emoticons': 0,
#     'hashtags': 0,
#     'urls': 0},
#    'liwc': {'scores': {'analytical_thinking': 1,
#      'authentic': 1,
#      'clout': 99,
#      'emotional_tone': 25.774193548387096,
#      'dictionary_words': 1,
#      'categories': {'achievement': 0,
#       'adjectives': 0,
#       'adverbs': 0.25,
#       'affect': 0,
#       'affiliation': 0.25,
#       'all_punctuation': 0.25,
#       'anger_words': 0,
#       'anxiety_words': 0,
#       'apostrophes': 0,
#       'articles': 0,
#       'assent': 0,
#       'auxiliary_verbs': 0.25,
#       'biological_processes': 0,
#       'body': 0,
#       'causation': 0.25,
#       'certainty': 0,
#       'cognitive_processes': 0.25,
#       'colons': 0,
#       'commas': 0,
#       'comparisons': 0,
#       'conjunctions': 0.25,
#       'dashes': 0,
#       'death': 0,
#       'differentiation': 0,
#       'discrepancies': 0,
#       'drives': 0.25,
#       'exclamations': 0,
#       'family': 0,
#       'feel': 0,
#       'female': 0,
#       'filler_words': 0,
#       'focus_future': 0,
#       'focus_past': 0,
#       'focus_present': 0.25,
#       'friends': 0,
#       'function_words': 0.75,
#       'health': 0,
#       'hear': 0,
#       'home': 0,
#       'i': 0,
#       'impersonal_pronouns': 0,
#       'informal_language': 0,
#       'ingestion': 0,
#       'insight': 0,
#       'interrogatives': 0.25,
#       'leisure': 0,
#       'male': 0,
#       'money': 0,
#       'motion': 0,
#       'negations': 0,
#       'negative_emotion_words': 0,
#       'netspeak': 0,
#       'nonfluencies': 0,
#       'numbers': 0,
#       'other_grammar': 0.5,
#       'other_punctuation': 0,
#       'parentheses': 0,
#       'perceptual_processes': 0,
#       'periods': 0,
#       'personal_concerns': 0,
#       'personal_pronouns': 0.25,
#       'positive_emotion_words': 0,
#       'power': 0,
#       'prepositions': 0,
#       'pronouns': 0.25,
#       'quantifiers': 0,
#       'question_marks': 0.25,
#       'quotes': 0,
#       'relativity': 0,
#       'religion': 0,
#       'reward': 0,
#       'risk': 0,
#       'sad_words': 0,
#       'see': 0,
#       'semicolons': 0,
#       'sexual': 0,
#       'she_he': 0,
#       'social': 0.5,
#       'space': 0,
#       'swear_words': 0,
#       'tentative': 0,
#       'they': 0,
#       'time': 0,
#       'time_orientation': 0.25,
#       'verbs': 0.25,
#       'we': 0,
#       'work': 0,
#       'you': 0.25}}},
#    'sallee': {'counts': {'emotions': {'admiration': 0,
#       'amusement': 0,
#       'anger': 0,
#       'boredom': 0,
#       'calmness': 0,
#       'curiosity': 0,
#       'desire': 0,
#       'disgust': 0,
#       'excitement': 0,
#       'fear': 0,
#       'gratitude': 0,
#       'joy': 0,
#       'love': 0,
#       'pain': 0,
#       'sadness': 0,
#       'shame': 0,
#       'surprise': 0,
#       'unspecified_bad': 0,
#       'unspecified_feel': 0,
#       'unspecified_good': 0},
#      'goodfeel': 0,
#      'ambifeel': 0,
#      'badfeel': 0,
#      'emotionality': 0,
#      'sentiment': 0,
#      'non_emotion': None},
#     'scores': {'emotions': {'admiration': 0,
#       'amusement': 0,
#       'anger': 0,
#       'boredom': 0,
#       'calmness': 0,
#       'curiosity': 0,
#       'desire': 0,
#       'disgust': 0,
#       'excitement': 0,
#       'fear': 0,
#       'gratitude': 0,
#       'joy': 0,
#       'love': 0,
#       'pain': 0,
#       'sadness': 0,
#       'shame': 0,
#       'surprise': 0,
#       'unspecified_bad': 0,
#       'unspecified_feel': 0,
#       'unspecified_good': 0},
#      'goodfeel': 0,
#      'ambifeel': 0,
#      'badfeel': 0,
#      'emotionality': 0,
#      'sentiment': 0,
#      'non_emotion': 1},
#     'emotion_word_count': 0},
#    'receptiviti': {'percentiles': {'active': 98.26157261992952,
#      'adjustment': 1,
#      'adventurous': 20.281966234770405,
#      'aggressive': 16.789779411809917,
#      'agreeableness': 92.40706719323278,
#      'ambitious': 28.619407743377373,
#      'analytical_thinking': 1,
#      'artistic': 7.4923836841981535,
#      'assertive': 66.77448414515088,
#      'authenticity': 6.550352067341323,
#      'cautious': 19.901469066913105,
#      'cold': 74.49070304989057,
#      'collaboration': 17.896141651493114,
#      'conscientiousness': 61.06835069035598,
#      'cooperative': 63.544288083598055,
#      'depressive_mood': 32.84418164422415,
#      'depressive_tone': 27.519034731619307,
#      'disciplined': 65.79075099552598,
#      'disengagement': 24.445474204384038,
#      'disgruntlement': 53.79801219874098,
#      'dissatisfaction': 70.88218750544631,
#      'dutiful': 80.23679499277644,
#      'emotional_tone': 82.45156572941902,
#      'emotionally_aware': 1.1273200750408732,
#      'empathetic': 93.7149273293946,
#      'empowerment': 31.402141028084166,
#      'energetic': 33.04009802784426,
#      'engagement': 63.733428331289055,
#      'extraversion': 90.05887964698287,
#      'family_oriented': 83.56087613293052,
#      'fatigue': 40.180304346593985,
#      'friendly': 45.70138598695792,
#      'generous': 99,
#      'genuine': 12.568852622782082,
#      'humble': 71.43368659844876,
#      'imaginative': 9.839202917700245,
#      'impulsive': 56.64075082113651,
#      'independence': 1,
#      'influence': 99,
#      'insecure': 85.47736920447655,
#      'intellectual': 1,
#      'inward_focus': 1,
#      'lack_of_energy': 6.1463253221358425,
#      'liberal': 45.176097200549215,
#      'negative_emotions': 19.188810912300212,
#      'neuroticism': 52.322153424158074,
#      'openness': 1,
#      'organized': 49.51113508411152,
#      'personal_achievement_drive': 5.672705037461388,
#      'persuasiveness': 94.12291306850892,
#      'power_driven': 1,
#      'risk_aversion': 63.4558134143076,
#      'satisfaction': 32.02575924818651,
#      'self_assured': 71.70708436763886,
#      'self_conscious': 62.172161925062866,
#      'sociable': 99,
#      'social_skills': 83.1093188268685,
#      'stress': 33.85840311904739,
#      'stressed': 82.52507999192724,
#      'trusting': 46.972085575416024,
#      'type_a': 5.8587620737236366,
#      'workhorse': 52.064156206415625},
#     'scores': {'active': 2.5,
#      'adjustment': -4.14257555847569,
#      'adventurous': 0,
#      'aggressive': 0,
#      'agreeableness': -0.75,
#      'ambitious': 2.5,
#      'analytical_thinking': -9.519386106623585,
#      'artistic': 0,
#      'assertive': 2.5,
#      'authenticity': 0,
#      'cautious': 0,
#      'cold': 0,
#      'collaboration': -5.9326601123595495,
#      'conscientiousness': 0.7833333333333332,
#      'cooperative': 5,
#      'depressive_mood': 0,
#      'depressive_tone': 0,
#      'disciplined': 2.5,
#      'disengagement': -0.9016730051964401,
#      'disgruntlement': 0,
#      'dissatisfaction': 0,
#      'dutiful': 0,
#      'emotional_tone': 0,
#      'emotionally_aware': -2.5,
#      'empathetic': 0,
#      'empowerment': 1.25,
#      'energetic': 0,
#      'engagement': 0.39974003902369715,
#      'extraversion': 1.885626767200754,
#      'family_oriented': 5,
#      'fatigue': 0,
#      'friendly': 2.35626767200754,
#      'generous': 1,
#      'genuine': -2.5,
#      'humble': 0,
#      'imaginative': -2.5,
#      'impulsive': 2.5,
#      'independence': -11.78630788646815,
#      'influence': 5,
#      'insecure': 2.5,
#      'intellectual': 0,
#      'inward_focus': -25,
#      'lack_of_energy': -19.71865,
#      'liberal': 0,
#      'negative_emotions': 8.127340823970037,
#      'neuroticism': 1.0994721764382702,
#      'openness': -1.25,
#      'organized': 0,
#      'personal_achievement_drive': 2.5,
#      'persuasiveness': 2.5,
#      'power_driven': -2.5,
#      'risk_aversion': 0,
#      'satisfaction': 0,
#      'self_assured': 2.5,
#      'self_conscious': 2.5,
#      'sociable': 7.5,
#      'social_skills': 2.5,
#      'stress': 5.622659176029963,
#      'stressed': 7.5,
#      'trusting': 0,
#      'type_a': 5,
#      'workhorse': -2.5}}}]}

# %% [markdown]
# ## Step 5 - Make a bulk call

# %%
print("Bulk Call to Receptiviti API")
result = call_receptiviti_api([
                                "Hi, How are you?", 
                                "Hello world! I love icecream and watermelons!"
                            ], call_type="bulk")
result
# Out:
# Bulk Call to Receptiviti API
# {'plan_usage': {'call_limit': 107007130,
#   'calls_made': 468996,
#   'calls_remaining': 106538134,
#   'percent_used': 0.44,
#   'start_date': '2020-11-01T00:00:00Z',
#   'end_date': '2020-11-30T23:59:59Z'},
#  'results': [{'response_id': '2378699e-d7f8-45c5-b2b7-abb290782888',
#    'language': 'en',
#    'version': 'v1.0.0',
#    'summary': {'word_count': 4,
#     'words_per_sentence': 4,
#     'sentence_count': 1,
#     'six_plus_words': 0,
#     'emojis': 0,
#     'emoticons': 0,
#     'hashtags': 0,
#     'urls': 0},
#    'liwc': {'scores': {'analytical_thinking': 1,
#      'authentic': 1,
#      'clout': 99,
#      'emotional_tone': 25.774193548387096,
#      'dictionary_words': 1,
#      'categories': {'achievement': 0,
#       'adjectives': 0,
#       'adverbs': 0.25,
#       'affect': 0,
#       'affiliation': 0.25,
#       'all_punctuation': 0.5,
#       'anger_words': 0,
#       'anxiety_words': 0,
#       'apostrophes': 0,
#       'articles': 0,
#       'assent': 0,
#       'auxiliary_verbs': 0.25,
#       'biological_processes': 0,
#       'body': 0,
#       'causation': 0.25,
#       'certainty': 0,
#       'cognitive_processes': 0.25,
#       'colons': 0,
#       'commas': 0.25,
#       'comparisons': 0,
#       'conjunctions': 0.25,
#       'dashes': 0,
#       'death': 0,
#       'differentiation': 0,
#       'discrepancies': 0,
#       'drives': 0.25,
#       'exclamations': 0,
#       'family': 0,
#       'feel': 0,
#       'female': 0,
#       'filler_words': 0,
#       'focus_future': 0,
#       'focus_past': 0,
#       'focus_present': 0.25,
#       'friends': 0,
#       'function_words': 0.75,
#       'health': 0,
#       'hear': 0,
#       'home': 0,
#       'i': 0,
#       'impersonal_pronouns': 0,
#       'informal_language': 0,
#       'ingestion': 0,
#       'insight': 0,
#       'interrogatives': 0.25,
#       'leisure': 0,
#       'male': 0,
#       'money': 0,
#       'motion': 0,
#       'negations': 0,
#       'negative_emotion_words': 0,
#       'netspeak': 0,
#       'nonfluencies': 0,
#       'numbers': 0,
#       'other_grammar': 0.5,
#       'other_punctuation': 0,
#       'parentheses': 0,
#       'perceptual_processes': 0,
#       'periods': 0,
#       'personal_concerns': 0,
#       'personal_pronouns': 0.25,
#       'positive_emotion_words': 0,
#       'power': 0,
#       'prepositions': 0,
#       'pronouns': 0.25,
#       'quantifiers': 0,
#       'question_marks': 0.25,
#       'quotes': 0,
#       'relativity': 0,
#       'religion': 0,
#       'reward': 0,
#       'risk': 0,
#       'sad_words': 0,
#       'see': 0,
#       'semicolons': 0,
#       'sexual': 0,
#       'she_he': 0,
#       'social': 0.5,
#       'space': 0,
#       'swear_words': 0,
#       'tentative': 0,
#       'they': 0,
#       'time': 0,
#       'time_orientation': 0.25,
#       'verbs': 0.25,
#       'we': 0,
#       'work': 0,
#       'you': 0.25}}},
#    'sallee': {'counts': {'emotions': {'admiration': 0,
#       'amusement': 0,
#       'anger': 0,
#       'boredom': 0,
#       'calmness': 0,
#       'curiosity': 0,
#       'desire': 0,
#       'disgust': 0,
#       'excitement': 0,
#       'fear': 0,
#       'gratitude': 0,
#       'joy': 0,
#       'love': 0,
#       'pain': 0,
#       'sadness': 0,
#       'shame': 0,
#       'surprise': 0,
#       'unspecified_bad': 0,
#       'unspecified_feel': 0,
#       'unspecified_good': 0},
#      'goodfeel': 0,
#      'ambifeel': 0,
#      'badfeel': 0,
#      'emotionality': 0,
#      'sentiment': 0,
#      'non_emotion': None},
#     'scores': {'emotions': {'admiration': 0,
#       'amusement': 0,
#       'anger': 0,
#       'boredom': 0,
#       'calmness': 0,
#       'curiosity': 0,
#       'desire': 0,
#       'disgust': 0,
#       'excitement': 0,
#       'fear': 0,
#       'gratitude': 0,
#       'joy': 0,
#       'love': 0,
#       'pain': 0,
#       'sadness': 0,
#       'shame': 0,
#       'surprise': 0,
#       'unspecified_bad': 0,
#       'unspecified_feel': 0,
#       'unspecified_good': 0},
#      'goodfeel': 0,
#      'ambifeel': 0,
#      'badfeel': 0,
#      'emotionality': 0,
#      'sentiment': 0,
#      'non_emotion': 1},
#     'emotion_word_count': 0},
#    'receptiviti': {'percentiles': {'active': 98.26157261992952,
#      'adjustment': 1,
#      'adventurous': 20.281966234770405,
#      'aggressive': 16.789779411809917,
#      'agreeableness': 92.40706719323278,
#      'ambitious': 28.619407743377373,
#      'analytical_thinking': 1,
#      'artistic': 7.4923836841981535,
#      'assertive': 66.77448414515088,
#      'authenticity': 6.550352067341323,
#      'cautious': 19.901469066913105,
#      'cold': 74.49070304989057,
#      'collaboration': 17.896141651493114,
#      'conscientiousness': 61.06835069035598,
#      'cooperative': 63.544288083598055,
#      'depressive_mood': 32.84418164422415,
#      'depressive_tone': 27.519034731619307,
#      'disciplined': 65.79075099552598,
#      'disengagement': 24.445474204384038,
#      'disgruntlement': 53.79801219874098,
#      'dissatisfaction': 70.88218750544631,
#      'dutiful': 80.23679499277644,
#      'emotional_tone': 82.45156572941902,
#      'emotionally_aware': 1.1273200750408732,
#      'empathetic': 93.7149273293946,
#      'empowerment': 31.402141028084166,
#      'energetic': 33.04009802784426,
#      'engagement': 63.733428331289055,
#      'extraversion': 90.05887964698287,
#      'family_oriented': 83.56087613293052,
#      'fatigue': 40.180304346593985,
#      'friendly': 45.70138598695792,
#      'generous': 99,
#      'genuine': 12.568852622782082,
#      'humble': 71.43368659844876,
#      'imaginative': 9.839202917700245,
#      'impulsive': 56.64075082113651,
#      'independence': 1,
#      'influence': 99,
#      'insecure': 85.47736920447655,
#      'intellectual': 1,
#      'inward_focus': 1,
#      'lack_of_energy': 6.1463253221358425,
#      'liberal': 45.176097200549215,
#      'negative_emotions': 19.188810912300212,
#      'neuroticism': 52.322153424158074,
#      'openness': 1,
#      'organized': 49.51113508411152,
#      'personal_achievement_drive': 5.672705037461388,
#      'persuasiveness': 94.12291306850892,
#      'power_driven': 1,
#      'risk_aversion': 63.4558134143076,
#      'satisfaction': 32.02575924818651,
#      'self_assured': 71.70708436763886,
#      'self_conscious': 62.172161925062866,
#      'sociable': 99,
#      'social_skills': 83.1093188268685,
#      'stress': 33.85840311904739,
#      'stressed': 82.52507999192724,
#      'trusting': 46.972085575416024,
#      'type_a': 5.8587620737236366,
#      'workhorse': 52.064156206415625},
#     'scores': {'active': 2.5,
#      'adjustment': -4.14257555847569,
#      'adventurous': 0,
#      'aggressive': 0,
#      'agreeableness': -0.75,
#      'ambitious': 2.5,
#      'analytical_thinking': -9.519386106623585,
#      'artistic': 0,
#      'assertive': 2.5,
#      'authenticity': 0,
#      'cautious': 0,
#      'cold': 0,
#      'collaboration': -5.9326601123595495,
#      'conscientiousness': 0.7833333333333332,
#      'cooperative': 5,
#      'depressive_mood': 0,
#      'depressive_tone': 0,
#      'disciplined': 2.5,
#      'disengagement': -0.9016730051964401,
#      'disgruntlement': 0,
#      'dissatisfaction': 0,
#      'dutiful': 0,
#      'emotional_tone': 0,
#      'emotionally_aware': -2.5,
#      'empathetic': 0,
#      'empowerment': 1.25,
#      'energetic': 0,
#      'engagement': 0.39974003902369715,
#      'extraversion': 1.885626767200754,
#      'family_oriented': 5,
#      'fatigue': 0,
#      'friendly': 2.35626767200754,
#      'generous': 1,
#      'genuine': -2.5,
#      'humble': 0,
#      'imaginative': -2.5,
#      'impulsive': 2.5,
#      'independence': -11.78630788646815,
#      'influence': 5,
#      'insecure': 2.5,
#      'intellectual': 0,
#      'inward_focus': -25,
#      'lack_of_energy': -19.71865,
#      'liberal': 0,
#      'negative_emotions': 8.127340823970037,
#      'neuroticism': 1.0994721764382702,
#      'openness': -1.25,
#      'organized': 0,
#      'personal_achievement_drive': 2.5,
#      'persuasiveness': 2.5,
#      'power_driven': -2.5,
#      'risk_aversion': 0,
#      'satisfaction': 0,
#      'self_assured': 2.5,
#      'self_conscious': 2.5,
#      'sociable': 7.5,
#      'social_skills': 2.5,
#      'stress': 5.622659176029963,
#      'stressed': 7.5,
#      'trusting': 0,
#      'type_a': 5,
#      'workhorse': -2.5}}},
#   {'response_id': 'a494b8c4-7463-49f1-906e-08dc91fb5cc0',
#    'language': 'en',
#    'version': 'v1.0.0',
#    'summary': {'word_count': 7,
#     'words_per_sentence': 3.5,
#     'sentence_count': 2,
#     'six_plus_words': 0.2857142857142857,
#     'emojis': 0,
#     'emoticons': 0,
#     'hashtags': 0,
#     'urls': 0},
#    'liwc': {'scores': {'analytical_thinking': 29.29697396199859,
#      'authentic': 89.63463203463203,
#      'clout': 92.33199195171026,
#      'emotional_tone': 99,
#      'dictionary_words': 0.7142857142857143,
#      'categories': {'achievement': 0,
#       'adjectives': 0,
#       'adverbs': 0,
#       'affect': 0.14285714285714285,
#       'affiliation': 0.2857142857142857,
#       'all_punctuation': 0.2857142857142857,
#       'anger_words': 0,
#       'anxiety_words': 0,
#       'apostrophes': 0,
#       'articles': 0,
#       'assent': 0,
#       'auxiliary_verbs': 0,
#       'biological_processes': 0.14285714285714285,
#       'body': 0,
#       'causation': 0,
#       'certainty': 0,
#       'cognitive_processes': 0,
#       'colons': 0,
#       'commas': 0,
#       'comparisons': 0,
#       'conjunctions': 0.14285714285714285,
#       'dashes': 0,
#       'death': 0,
#       'differentiation': 0,
#       'discrepancies': 0,
#       'drives': 0.2857142857142857,
#       'exclamations': 0.2857142857142857,
#       'family': 0,
#       'feel': 0,
#       'female': 0,
#       'filler_words': 0,
#       'focus_future': 0,
#       'focus_past': 0,
#       'focus_present': 0,
#       'friends': 0,
#       'function_words': 0.2857142857142857,
#       'health': 0,
#       'hear': 0,
#       'home': 0,
#       'i': 0.14285714285714285,
#       'impersonal_pronouns': 0,
#       'informal_language': 0,
#       'ingestion': 0,
#       'insight': 0,
#       'interrogatives': 0,
#       'leisure': 0,
#       'male': 0,
#       'money': 0,
#       'motion': 0,
#       'negations': 0,
#       'negative_emotion_words': 0,
#       'netspeak': 0,
#       'nonfluencies': 0,
#       'numbers': 0,
#       'other_grammar': 0,
#       'other_punctuation': 0,
#       'parentheses': 0,
#       'perceptual_processes': 0,
#       'periods': 0,
#       'personal_concerns': 0,
#       'personal_pronouns': 0.14285714285714285,
#       'positive_emotion_words': 0.14285714285714285,
#       'power': 0,
#       'prepositions': 0,
#       'pronouns': 0.14285714285714285,
#       'quantifiers': 0,
#       'question_marks': 0,
#       'quotes': 0,
#       'relativity': 0.14285714285714285,
#       'religion': 0,
#       'reward': 0,
#       'risk': 0,
#       'sad_words': 0,
#       'see': 0,
#       'semicolons': 0,
#       'sexual': 0,
#       'she_he': 0,
#       'social': 0.2857142857142857,
#       'space': 0.14285714285714285,
#       'swear_words': 0,
#       'tentative': 0,
#       'they': 0,
#       'time': 0,
#       'time_orientation': 0,
#       'verbs': 0,
#       'we': 0,
#       'work': 0,
#       'you': 0}}},
#    'sallee': {'counts': {'emotions': {'admiration': 0,
#       'amusement': 0,
#       'anger': 0,
#       'boredom': 0,
#       'calmness': 0,
#       'curiosity': 0,
#       'desire': 0,
#       'disgust': 0,
#       'excitement': 0.73,
#       'fear': 0,
#       'gratitude': 0,
#       'joy': 0,
#       'love': 5.73,
#       'pain': 0,
#       'sadness': 0,
#       'shame': 0,
#       'surprise': 0,
#       'unspecified_bad': 0,
#       'unspecified_feel': 0,
#       'unspecified_good': 0},
#      'goodfeel': 6.460000000000001,
#      'ambifeel': 0,
#      'badfeel': 0,
#      'emotionality': 6.460000000000001,
#      'sentiment': 6.460000000000001,
#      'non_emotion': None},
#     'scores': {'emotions': {'admiration': 0,
#       'amusement': 0,
#       'anger': 0,
#       'boredom': 0,
#       'calmness': 0,
#       'curiosity': 0,
#       'desire': 0,
#       'disgust': 0,
#       'excitement': 0.10347923672744726,
#       'fear': 0,
#       'gratitude': 0,
#       'joy': 0,
#       'love': 0.47533897748456516,
#       'pain': 0,
#       'sadness': 0,
#       'shame': 0,
#       'surprise': 0,
#       'unspecified_bad': 0,
#       'unspecified_feel': 0,
#       'unspecified_good': 0},
#      'goodfeel': 0.5636998254799302,
#      'ambifeel': 0,
#      'badfeel': 0,
#      'emotionality': 0.5636998254799302,
#      'sentiment': 0.5909183737369875,
#      'non_emotion': 0.43630017452006975},
#     'emotion_word_count': 2,
#     'emotion_words': [{'text': 'NO_EMOTIONS_FOUND',
#       'sentence': 1,
#       'emotions': {'excitement': 0.73},
#       'modifiers': [{'action': 'exclamation',
#         'text': '',
#         'index': 0,
#         'weight': 0.73}]},
#      {'text': 'love',
#       'sentence': 3,
#       'emotions': {'love': 5},
#       'modifiers': [{'action': 'exclamation',
#         'text': '',
#         'index': 0,
#         'weight': 0.73}]}]},
#    'receptiviti': {'percentiles': {'active': 41.800977049302205,
#      'adjustment': 5.0497040835997025,
#      'adventurous': 20.281966234770405,
#      'aggressive': 4.188798441663791,
#      'agreeableness': 95.90710253795693,
#      'ambitious': 17.379864346325878,
#      'analytical_thinking': 5.17705407596478,
#      'artistic': 22.878260816151258,
#      'assertive': 31.48584541269147,
#      'authenticity': 94.957234272817,
#      'cautious': 19.901469066913105,
#      'cold': 74.49070304989057,
#      'collaboration': 99,
#      'conscientiousness': 45.610048006526384,
#      'cooperative': 86.207463726486,
#      'depressive_mood': 89.76261583399507,
#      'depressive_tone': 27.519034731619307,
#      'disciplined': 65.79075099552598,
#      'disengagement': 24.162234479897556,
#      'disgruntlement': 13.34416281163214,
#      'dissatisfaction': 18.01170778764764,
#      'dutiful': 81.13027980836132,
#      'emotional_tone': 99,
#      'emotionally_aware': 70.8572674298971,
#      'empathetic': 72.30582496818836,
#      'empowerment': 4.850055528542116,
#      'energetic': 79.83674857721311,
#      'engagement': 88.97936225221234,
#      'extraversion': 80.57975360914752,
#      'family_oriented': 29.650380247942497,
#      'fatigue': 40.180304346593985,
#      'friendly': 48.92615666276711,
#      'generous': 96.55718315221601,
#      'genuine': 84.16464441876887,
#      'humble': 71.43368659844876,
#      'imaginative': 99,
#      'impulsive': 56.64075082113651,
#      'independence': 19.77078082195607,
#      'influence': 60.633778518693276,
#      'insecure': 85.47736920447655,
#      'intellectual': 3.5625083157885555,
#      'inward_focus': 27.248302870625672,
#      'lack_of_energy': 8.077371241049839,
#      'liberal': 45.176097200549215,
#      'negative_emotions': 24.71420009931718,
#      'neuroticism': 45.60704568193354,
#      'openness': 80.1092711759824,
#      'organized': 49.51113508411152,
#      'personal_achievement_drive': 4.161669836268107,
#      'persuasiveness': 82.10698425493243,
#      'power_driven': 1,
#      'risk_aversion': 63.4558134143076,
#      'satisfaction': 93.45814681903548,
#      'self_assured': 21.1861394974359,
#      'self_conscious': 95.11482359836666,
#      'sociable': 99,
#      'social_skills': 99,
#      'stress': 58.87041845208634,
#      'stressed': 71.02325824558778,
#      'trusting': 46.972085575416024,
#      'type_a': 1,
#      'workhorse': 88.74719271895005},
#     'scores': {'active': -2.5,
#      'adjustment': -2.1099221108965196,
#      'adventurous': 0,
#      'aggressive': -2.5,
#      'agreeableness': -0.027524544179523214,
#      'ambitious': 1.4357501794687724,
#      'analytical_thinking': -3.653934918070621,
#      'artistic': 1.25,
#      'assertive': 1.1713075060532683,
#      'authenticity': 3.730466346745416,
#      'cautious': 0,
#      'cold': 0,
#      'collaboration': 20.311122742094255,
#      'conscientiousness': 0.38059851314684817,
#      'cooperative': 7.5,
#      'depressive_mood': 5,
#      'depressive_tone': 0,
#      'disciplined': 2.5,
#      'disengagement': -0.909428053283512,
#      'disgruntlement': -2.5,
#      'dissatisfaction': -7.5,
#      'dutiful': 0.07869249394673172,
#      'emotional_tone': 2.5,
#      'emotionally_aware': 2.5,
#      'empathetic': -1.0018032458425166,
#      'empowerment': -1.25,
#      'energetic': 2.5,
#      'engagement': 0.7863257903807686,
#      'extraversion': 1.4976508855820667,
#      'family_oriented': 2.5,
#      'fatigue': 0,
#      'friendly': 2.5,
#      'generous': -0.0018032458425165654,
#      'genuine': 0,
#      'humble': 0,
#      'imaginative': 2.5,
#      'impulsive': 2.5,
#      'independence': -6.528420279394688,
#      'influence': 0,
#      'insecure': 2.5,
#      'intellectual': 3.663003663003663,
#      'inward_focus': -3.5014005602240914,
#      'lack_of_energy': -18.41485,
#      'liberal': 0,
#      'negative_emotions': 9.250700280112042,
#      'neuroticism': 0.986997197971424,
#      'openness': 1.59981684981685,
#      'organized': 0,
#      'personal_achievement_drive': 1.7507002801120446,
#      'persuasiveness': 1.0018032458425168,
#      'power_driven': 1.0018032458425166,
#      'risk_aversion': 0,
#      'satisfaction': 2.5,
#      'self_assured': 0,
#      'self_conscious': 5,
#      'sociable': 8.935750179468773,
#      'social_skills': 4.921307506053268,
#      'stress': 7.5,
#      'stressed': 6.435750179468773,
#      'trusting': 0,
#      'type_a': 2.5,
#      'workhorse': 0}}}]}
